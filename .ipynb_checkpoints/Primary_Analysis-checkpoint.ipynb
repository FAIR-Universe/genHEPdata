# %% [markdown]
# # Primary Data Analysis - FAIR UNIVERSE: HIGGSML UNCERTAINTY CHALLENGE
#
# For Primary Analysis of the datasets

# %% [markdown]
# ### Imports

# %%
from sys import path
import numpy as np
import pandas as pd
import json
import warnings
import os
import sys
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Directories

# %%
root_dir = os.getcwd()
print("Root directory is", root_dir)

input_dir = "/global/cfs/cdirs/m4287/hep/NEW_DelphesPythia_data/Full_data_files_20240826/sample_data/input_data/"
ingestion_dir = "/global/cfs/cdirs/m4287/hep/HEP-Challenge/ingestion_program/"

path.append(ingestion_dir)
from derived_quantities import DER_data
from systematics import systematics
# Out:
# Root directory is /global/cfs/cdirs/m4287/hep/genHEPdata

# %% [markdown]
# ***
# # Internal imports
# ***

# %%
from visualization import *
from datasets import Data

# %% [markdown]
# ***
# ## Data
# ***

# %%
data = Data(input_dir)

# %%
# load train set
data.load_train_set()
# Out:
# 2024-09-16 08:28:51,035 - datasets             - INFO     - Train data loaded successfully

# %%
# load test sets
data.load_test_set()
# Out:
# 2024-09-16 08:28:51,091 - datasets             - INFO     - Test data loaded successfully

# %% [markdown]
# ***
# # Visualize
# ***
# - Visualize Train set

# %%
data_vis = (data.get_train_set()).copy()

data_vis = systematics(data_vis, dopostprocess=False)

type(data_vis)

train_visualize = Dataset_visualise(
    data_set=data_vis,
    name="Train Set",
)

train_visualize.examine_dataset()
# Out:
# [*] --- Dataset name : Train Set
# [*] --- Number of events : 220790
# [*] --- Number of features : 28
#    diboson   3782.6381793477562
#    htautau   1015.3650915154886
#    ttbar   44190.17414223769
#    ztautau   1002396.6246678493
# [*] --- Number of signal events : 213
# [*] --- Number of background events : 220577
# [*] --- Examples of all features
#    PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_had_pt  PRI_had_eta  PRI_had_phi  \
# 0   25.412001       -0.555        1.975   28.997999        0.351       -1.838
# 1   39.563000        0.586        3.058   28.274000        0.735        0.084
# 2   22.320000        0.801        2.521   29.041000       -0.735       -0.864
# 3   46.730999        2.417       -1.388   24.281000        0.999        0.822
# 4   24.546000        2.164        1.908   38.452999        0.426       -2.151
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0           54.056000                1.636               -0.244
# 1          -25.000000              -25.000              -25.000
# 2           26.881001               -1.195                0.180
# 3           48.387001                1.524                2.458
# 4          -25.000000              -25.000              -25.000
#
#    PRI_jet_subleading_pt  ...   DER_pt_h  DER_deltaeta_jet_jet  \
# 0                 26.354  ...  24.689272                 1.513
# 1                -25.000  ...   4.905827               -25.000
# 2                -25.000  ...  17.722971               -25.000
# 3                -25.000  ...  40.954529               -25.000
# 4                -25.000  ...  40.089237               -25.000
#
#    DER_mass_jet_jet  DER_prodeta_jet_jet  DER_deltar_had_lep  DER_pt_tot  \
# 0         95.622383             5.151764            2.631094   12.235117
# 1        -25.000000           -25.000000            2.977730    4.905827
# 2        -25.000000           -25.000000            3.280057   12.030704
# 3        -25.000000           -25.000000            2.625800   16.690060
# 4        -25.000000           -25.000000            2.822702   40.089237
#
#    DER_sum_pt  DER_pt_ratio_lep_had  DER_met_phi_centrality  \
# 0  134.820007              0.876336                0.701390
# 1   67.836998              1.399271               -1.390982
# 2   78.242004              0.768569                1.092476
# 3  119.399002              1.924591                1.011077
# 4   62.999001              0.638338                1.252621
#
#    DER_lep_eta_centrality
# 0            2.553498e-07
# 1           -2.500000e+01
# 2           -2.500000e+01
# 3           -2.500000e+01
# 4           -2.500000e+01
#
# [5 rows x 28 columns]
# [*] --- Description of all features
#           PRI_lep_pt    PRI_lep_eta    PRI_lep_phi     PRI_had_pt  \
# count  220790.000000  220790.000000  220790.000000  220790.000000
# mean       31.055374      -0.000944       0.002016      38.704414
# std        14.344219       1.253223       1.814760      15.158712
# min        20.000000      -2.500000      -3.142000      22.924999
# 25%        23.336000      -0.992000      -1.573000      29.621000
# 50%        27.530001      -0.004000       0.001000      35.813999
# 75%        33.839750       0.989000       1.580000      43.429001
# max       515.867004       2.500000       3.142000     464.765015
#
#          PRI_had_eta   PRI_had_phi  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  220790.000000  220790.00000       220790.000000        220790.000000
# mean       -0.001035      -0.00532            5.796089           -15.776700
# std         1.272968       1.81164           48.654831            12.114539
# min        -2.673000      -3.14200          -25.000000           -25.000000
# 25%        -1.012000      -1.57400          -25.000000           -25.000000
# 50%        -0.006000      -0.00400          -25.000000           -25.000000
# 75%         1.011000       1.55875           32.217999            -0.903000
# max         2.668000       3.14200          780.448975             4.892000
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  ...       DER_pt_h  \
# count        220790.000000          220790.000000  ...  220790.000000
# mean            -15.782240             -14.784845  ...      29.574652
# std              12.107629              27.031937  ...      37.091988
# min             -25.000000             -25.000000  ...       0.011628
# 25%             -25.000000             -25.000000  ...       9.184724
# 50%             -25.000000             -25.000000  ...      16.899858
# 75%              -1.138000             -25.000000  ...      33.099360
# max               3.142000             490.860992  ...     705.035400
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# count         220790.000000     220790.000000        220790.000000
# mean             -21.107067          7.820550           -21.302382
# std                9.492624        112.908913             9.099486
# min              -25.000000        -25.000000           -25.000000
# 25%              -25.000000        -25.000000           -25.000000
# 50%              -25.000000        -25.000000           -25.000000
# 75%              -25.000000        -25.000000           -25.000000
# max                8.573000       4245.830078            21.881567
#
#        DER_deltar_had_lep     DER_pt_tot     DER_sum_pt  DER_pt_ratio_lep_had  \
# count       220790.000000  220790.000000  220790.000000         220790.000000
# mean             2.838514      16.113491     101.521751              0.864556
# std              0.534164      13.661931      81.516579              0.422087
# min              0.591869       0.011628      42.925999              0.053625
# 25%              2.697879       7.783523      60.550003              0.616368
# 50%              3.013932      13.107084      72.680000              0.783541
# 75%              3.142860      20.557250     105.370752              1.000000
# max              5.649345     404.146729    1582.538086             14.541198
#
#        DER_met_phi_centrality  DER_lep_eta_centrality
# count           220790.000000           220790.000000
# mean                 0.157846              -21.337738
# std                  1.256730                8.916926
# min                 -1.414214              -25.000000
# 25%                 -1.382546              -25.000000
# 50%                  0.820928              -25.000000
# 75%                  1.392096              -25.000000
# max                  1.414214                1.000000
#
# [8 rows x 28 columns]

# %%
# Show data summary
train_visualize.histogram_dataset()

# %%
# train_visualize.stacked_histogram("PRI_n_jets")

# %%
# test_set = data.get_test_set()

# %%
# for key in test_set.keys():
#     data_test = test_set[key]
#     sum_weight = np.sum(data_test["weights"])
#     print(key, " ", sum_weight)

# %%
syst_train_data = data.get_syst_train_set(tes=0.9) # you can use other systematics like jes, softmet, etc.

# %%
train_visualize.histogram_syst(syst_train_data['data'],syst_train_data['weights'],columns=['PRI_had_pt','PRI_met','DER_deltar_had_lep','DER_mass_vis','DER_mass_transverse_met_lep'])

# %%
train_visualize.event_vise_syst(syst_train_data['data'],sample_size=200,columns=['PRI_had_pt','PRI_met','DER_deltar_had_lep','DER_mass_vis','DER_mass_transverse_met_lep'])
# Out:
# df_sample (200, 29)
# df_sample_syst (200, 29)

# %%
train_visualize.event_vise_syst_arrow(syst_train_data['data'],sample_size=30,columns=['PRI_had_pt','PRI_met','DER_deltar_had_lep','DER_mass_vis','DER_mass_transverse_met_lep'])
# Out:
# df_sample (30, 29)
# df_sample_syst (30, 29)
